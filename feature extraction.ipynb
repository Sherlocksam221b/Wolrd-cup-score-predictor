# %%
import pandas as pd
import numpy as np
import pickle

# %%
df=pickle.load(open('dataset_level2.pkl','rb'))

# %%
#coloumn needed for model building
df
#batting_team
#bowling_team
#curret_score
#wicket_left
#current_rr
#city
#ball_left
#score_in_last_five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 115320  Colombo       R Premadasa Stadium
# 115321  Colombo       R Premadasa Stadium
# 115322  Colombo       R Premadasa Stadium
# 115323  Colombo       R Premadasa Stadium
# 115324  Colombo       R Premadasa Stadium
#
# [70891 rows x 8 columns]

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3916
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Sylhet Stadium                              122
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
cities
# Out:
# array(['Melbourne', 'Melbourne', 'Melbourne', ..., 'Colombo', 'Colombo',
#        'Colombo'], dtype=object)

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [70891 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Dubai',
#  'Mirpur',
#  'Johannesburg',
#  'London',
#  'Auckland',
#  'Cape Town',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Abu Dhabi',
#  'Nottingham',
#  'Chittagong',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Mumbai',
#  'Southampton',
#  'Mount Maunganui',
#  'Kolkata',
#  'Lahore',
#  'Greater Noida',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
df=df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [54086 rows x 7 columns]

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\1859481337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\1859481337.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# 2       Melbourne              1
# 3       Melbourne              3
# 4       Melbourne              3
# ...           ...            ...
# 115320    Colombo            125
# 115321    Colombo            125
# 115322    Colombo            125
# 115323    Colombo            127
# 115324    Colombo            128
#
# [54086 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# 1       Melbourne              0    0       2
# 2       Melbourne              1    0       3
# 3       Melbourne              3    0       4
# 4       Melbourne              3    0       5
# ...           ...            ...  ...     ...
# 115320    Colombo            125   19       3
# 115321    Colombo            125   19       4
# 115322    Colombo            125   19       5
# 115323    Colombo            127   19       6
# 115324    Colombo            128   19       7
#
# [54086 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled
# 0       Melbourne              0    0       1             1
# 1       Melbourne              0    0       2             2
# 2       Melbourne              1    0       3             3
# 3       Melbourne              3    0       4             4
# 4       Melbourne              3    0       5             5
# ...           ...            ...  ...     ...           ...
# 115320    Colombo            125   19       3           117
# 115321    Colombo            125   19       4           118
# 115322    Colombo            125   19       5           119
# 115323    Colombo            127   19       6           120
# 115324    Colombo            128   19       7           121
#
# [54086 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled  balls_left
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
# [54086 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)


df['player_dismissed'] = df['player_dismissed'].astype(int)



df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].transform('cumsum')


df['wickets_left'] = 10 - df['player_dismissed']


print(df[['match_id', 'player_dismissed', 'wickets_left']].head())
# Out:
#    match_id  player_dismissed  wickets_left
# 0         2                 0            10
# 1         2                 0            10
# 2         2                 0            10
# 3         2                 0            10
# 4         2                 0            10
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\459262421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\459262421.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype(int)
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\459262421.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].transform('cumsum')
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\459262421.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                 10
# ...              ...
# 115320             2
# 115321             2
# 115322             1
# 115323             1
# 115324             1
#
# [54086 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left       crr
# 0                 10  0.000000
# 1                 10  0.000000
# 2                 10  2.000000
# 3                 10  4.500000
# 4                 10  3.600000
# ...              ...       ...
# 115320             2  6.410256
# 115321             2  6.355932
# 115322             1  6.302521
# 115323             1  6.350000
# 115324             1  6.347107
#
# [54086 rows x 14 columns]

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
groups = df.groupby('match_id')


last_thirty_sum = []

for match_id, group in groups:
    rolling_sum = group['runs'].rolling(window=30).sum().tolist()
    last_thirty_sum.extend(rolling_sum)
    
df['last_five'] = last_thirty_sum
# Out:
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\1056626474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
# C:\Users\samar\AppData\Local\Temp\ipykernel_8856\1056626474.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_thirty_sum

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left       crr  last_five
# 0                 10  0.000000        NaN
# 1                 10  0.000000        NaN
# 2                 10  2.000000        NaN
# 3                 10  4.500000        NaN
# 4                 10  3.600000        NaN
# ...              ...       ...        ...
# 115320             2  6.410256       32.0
# 115321             2  6.355932       32.0
# 115322             1  6.302521       32.0
# 115323             1  6.350000       33.0
# 115324             1  6.347107       32.0
#
# [54086 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 54081    Sri Lanka    Australia    Colombo            125           3
# 54082    Sri Lanka    Australia    Colombo            125           2
# 54083    Sri Lanka    Australia    Colombo            125           1
# 54084    Sri Lanka    Australia    Colombo            127           0
# 54085    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 54081             2  6.410256       32.0     128
# 54082             2  6.355932       32.0     128
# 54083             1  6.302521       32.0     128
# 54084             1  6.350000       33.0     128
# 54085             1  6.347107       32.0     128
#
# [54086 rows x 9 columns]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#       batting_team  bowling_team        city  current_score  balls_left  \
# 37397  Netherlands       Ireland       Dubai            103          12
# 28306   Bangladesh   New Zealand    Hamilton             52          60
# 45371   Bangladesh     Sri Lanka  Chittagong             92          22
# 48558    Australia         India      Sydney             54          87
# 21896      Ireland         India  Nottingham             48          60
# ...            ...           ...         ...            ...         ...
# 25495  West Indies     Australia      Sydney             90          28
# 41055     Pakistan  South Africa       Dubai             44          56
# 51660      England   Afghanistan       Delhi            126           7
# 52737  New Zealand       England       Delhi            109          37
# 32865  West Indies       England      London             85          43
#
#        wickets_left       crr  last_five  runs_x
# 37397             5  5.722222       29.0     114
# 28306             5  5.200000       21.0      78
# 45371             3  5.632653       29.0     120
# 48558             9  9.818182       53.0     197
# 21896             5  4.800000       24.0     112
# ...             ...       ...        ...     ...
# 25495             4  5.869565       30.0     138
# 41055             5  4.125000       26.0      98
# 51660             3  6.690265       45.0     142
# 52737             7  7.879518       31.0     153
# 32865             8  6.623377       29.0     125
#
# [54086 rows x 9 columns]

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/a2/48/d5da8591891327b0faf08179d420fba3893c6134bdd449497c5329e4cb01/xgboost-2.1.0-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.1.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\samar\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\samar\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.1.0-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 653.6 kB/s eta 0:03:12
#    ---------------------------------------- 0.2/124.9 MB 2.5 MB/s eta 0:00:50
#    ---------------------------------------- 0.6/124.9 MB 4.1 MB/s eta 0:00:31
#    ---------------------------------------- 0.8/124.9 MB 4.3 MB/s eta 0:00:29
#    ---------------------------------------- 1.3/124.9 MB 5.5 MB/s eta 0:00:23
#     --------------------------------------- 1.9/124.9 MB 6.2 MB/s eta 0:00:20
#     --------------------------------------- 2.2/124.9 MB 6.8 MB/s eta 0:00:19
#     --------------------------------------- 2.3/124.9 MB 6.7 MB/s eta 0:00:19
#     --------------------------------------- 3.0/124.9 MB 7.2 MB/s eta 0:00:18
#    - -------------------------------------- 3.3/124.9 MB 7.5 MB/s eta 0:00:17
#    - -------------------------------------- 3.3/124.9 MB 7.5 MB/s eta 0:00:17
#    - -------------------------------------- 3.7/124.9 MB 7.1 MB/s eta 0:00:17
#    - -------------------------------------- 4.4/124.9 MB 7.2 MB/s eta 0:00:17
#    - -------------------------------------- 4.6/124.9 MB 7.0 MB/s eta 0:00:18
#    - -------------------------------------- 4.8/124.9 MB 7.2 MB/s eta 0:00:17
#    - -------------------------------------- 5.1/124.9 MB 7.1 MB/s eta 0:00:17
#    - -------------------------------------- 5.3/124.9 MB 6.8 MB/s eta 0:00:18
#    - -------------------------------------- 5.6/124.9 MB 6.7 MB/s eta 0:00:18
#    - -------------------------------------- 5.8/124.9 MB 6.7 MB/s eta 0:00:18
#    - -------------------------------------- 6.1/124.9 MB 6.6 MB/s eta 0:00:19
#    -- ------------------------------------- 6.3/124.9 MB 6.5 MB/s eta 0:00:19
#    -- ------------------------------------- 6.6/124.9 MB 6.4 MB/s eta 0:00:19
#    -- ------------------------------------- 6.8/124.9 MB 6.4 MB/s eta 0:00:19
#    -- ------------------------------------- 7.0/124.9 MB 6.3 MB/s eta 0:00:19
#    -- ------------------------------------- 7.2/124.9 MB 6.2 MB/s eta 0:00:19
#    -- ------------------------------------- 7.4/124.9 MB 6.2 MB/s eta 0:00:20
#    -- ------------------------------------- 7.6/124.9 MB 6.2 MB/s eta 0:00:20
#    -- ------------------------------------- 7.9/124.9 MB 6.1 MB/s eta 0:00:20
#    -- ------------------------------------- 8.1/124.9 MB 6.0 MB/s eta 0:00:20
#    -- ------------------------------------- 8.4/124.9 MB 6.0 MB/s eta 0:00:20
#    -- ------------------------------------- 8.7/124.9 MB 6.0 MB/s eta 0:00:20
#    -- ------------------------------------- 9.0/124.9 MB 6.0 MB/s eta 0:00:20
#    -- ------------------------------------- 9.2/124.9 MB 6.0 MB/s eta 0:00:20
#    --- ------------------------------------ 9.6/124.9 MB 6.0 MB/s eta 0:00:20
#    --- ------------------------------------ 9.8/124.9 MB 6.0 MB/s eta 0:00:20
#    --- ------------------------------------ 10.0/124.9 MB 6.0 MB/s eta 0:00:20
#    --- ------------------------------------ 10.3/124.9 MB 6.2 MB/s eta 0:00:19
#    --- ------------------------------------ 10.6/124.9 MB 6.1 MB/s eta 0:00:19
#    --- ------------------------------------ 10.9/124.9 MB 6.3 MB/s eta 0:00:19
#    --- ------------------------------------ 11.2/124.9 MB 6.2 MB/s eta 0:00:19
#    --- ------------------------------------ 11.6/124.9 MB 6.1 MB/s eta 0:00:19
#    --- ------------------------------------ 11.8/124.9 MB 6.1 MB/s eta 0:00:19
#    --- ------------------------------------ 12.1/124.9 MB 6.0 MB/s eta 0:00:19
#    --- ------------------------------------ 12.4/124.9 MB 6.0 MB/s eta 0:00:19
#    ---- ----------------------------------- 12.7/124.9 MB 6.0 MB/s eta 0:00:19
#    ---- ----------------------------------- 13.0/124.9 MB 5.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 13.3/124.9 MB 5.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 13.6/124.9 MB 5.9 MB/s eta 0:00:19
#    ---- ----------------------------------- 14.0/124.9 MB 6.0 MB/s eta 0:00:19
#    ---- ----------------------------------- 14.2/124.9 MB 5.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 14.6/124.9 MB 5.7 MB/s eta 0:00:20
#    ---- ----------------------------------- 14.9/124.9 MB 5.7 MB/s eta 0:00:20
#    ---- ----------------------------------- 15.2/124.9 MB 5.7 MB/s eta 0:00:20
#    ---- ----------------------------------- 15.6/124.9 MB 5.8 MB/s eta 0:00:19
#    ----- ---------------------------------- 15.9/124.9 MB 5.9 MB/s eta 0:00:19
#    ----- ---------------------------------- 16.2/124.9 MB 6.0 MB/s eta 0:00:19
#    ----- ---------------------------------- 16.5/124.9 MB 6.0 MB/s eta 0:00:19
#    ----- ---------------------------------- 16.8/124.9 MB 6.0 MB/s eta 0:00:18
#    ----- ---------------------------------- 17.2/124.9 MB 6.2 MB/s eta 0:00:18
#    ----- ---------------------------------- 17.4/124.9 MB 6.2 MB/s eta 0:00:18
#    ----- ---------------------------------- 17.7/124.9 MB 6.2 MB/s eta 0:00:18
#    ----- ---------------------------------- 18.0/124.9 MB 6.3 MB/s eta 0:00:17
#    ----- ---------------------------------- 18.2/124.9 MB 6.2 MB/s eta 0:00:18
#    ----- ---------------------------------- 18.5/124.9 MB 6.2 MB/s eta 0:00:18
#    ------ --------------------------------- 18.8/124.9 MB 6.3 MB/s eta 0:00:17
#    ------ --------------------------------- 19.1/124.9 MB 6.2 MB/s eta 0:00:17
#    ------ --------------------------------- 19.3/124.9 MB 6.2 MB/s eta 0:00:17
#    ------ --------------------------------- 19.6/124.9 MB 6.2 MB/s eta 0:00:18
#    ------ --------------------------------- 19.8/124.9 MB 6.2 MB/s eta 0:00:18
#    ------ --------------------------------- 20.1/124.9 MB 6.3 MB/s eta 0:00:17
#    ------ --------------------------------- 20.3/124.9 MB 6.1 MB/s eta 0:00:18
#    ------ --------------------------------- 20.5/124.9 MB 6.1 MB/s eta 0:00:18
#    ------ --------------------------------- 20.8/124.9 MB 6.2 MB/s eta 0:00:17
#    ------ --------------------------------- 21.1/124.9 MB 6.1 MB/s eta 0:00:17
#    ------ --------------------------------- 21.4/124.9 MB 6.2 MB/s eta 0:00:17
#    ------ --------------------------------- 21.7/124.9 MB 6.1 MB/s eta 0:00:18
#    ------- -------------------------------- 22.0/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 22.3/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 22.6/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 22.8/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 23.1/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 23.4/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 23.7/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 24.0/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 24.3/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 24.6/124.9 MB 6.1 MB/s eta 0:00:17
#    ------- -------------------------------- 24.9/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 25.3/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 25.6/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 25.9/124.9 MB 6.0 MB/s eta 0:00:17
#    -------- ------------------------------- 26.3/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 26.6/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 26.9/124.9 MB 6.0 MB/s eta 0:00:17
#    -------- ------------------------------- 27.2/124.9 MB 6.1 MB/s eta 0:00:17
#    -------- ------------------------------- 27.6/124.9 MB 6.1 MB/s eta 0:00:16
#    -------- ------------------------------- 27.9/124.9 MB 6.2 MB/s eta 0:00:16
#    --------- ------------------------------ 28.3/124.9 MB 6.2 MB/s eta 0:00:16
#    --------- ------------------------------ 28.6/124.9 MB 6.2 MB/s eta 0:00:16
#    --------- ------------------------------ 28.9/124.9 MB 6.2 MB/s eta 0:00:16
#    --------- ------------------------------ 29.3/124.9 MB 6.3 MB/s eta 0:00:16
#    --------- ------------------------------ 29.5/124.9 MB 6.3 MB/s eta 0:00:16
#    --------- ------------------------------ 29.8/124.9 MB 6.4 MB/s eta 0:00:15
#    --------- ------------------------------ 30.1/124.9 MB 6.3 MB/s eta 0:00:16
#    --------- ------------------------------ 30.3/124.9 MB 6.3 MB/s eta 0:00:16
#    --------- ------------------------------ 30.6/124.9 MB 6.4 MB/s eta 0:00:15
#    --------- ------------------------------ 30.9/124.9 MB 6.4 MB/s eta 0:00:15
#    --------- ------------------------------ 31.2/124.9 MB 6.4 MB/s eta 0:00:15
#    ---------- ----------------------------- 31.4/124.9 MB 6.4 MB/s eta 0:00:15
#    ---------- ----------------------------- 31.7/124.9 MB 6.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 32.0/124.9 MB 6.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 32.3/124.9 MB 6.4 MB/s eta 0:00:15
#    ---------- ----------------------------- 32.5/124.9 MB 6.4 MB/s eta 0:00:15
#    ---------- ----------------------------- 32.8/124.9 MB 6.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 33.0/124.9 MB 6.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 33.2/124.9 MB 6.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 33.6/124.9 MB 6.2 MB/s eta 0:00:15
#    ---------- ----------------------------- 33.9/124.9 MB 6.4 MB/s eta 0:00:15
#    ---------- ----------------------------- 34.2/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 34.5/124.9 MB 6.4 MB/s eta 0:00:15
#    ----------- ---------------------------- 34.8/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 35.1/124.9 MB 6.4 MB/s eta 0:00:15
#    ----------- ---------------------------- 35.4/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 35.7/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 36.1/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 36.4/124.9 MB 6.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 36.5/124.9 MB 6.2 MB/s eta 0:00:15
#    ----------- ---------------------------- 36.8/124.9 MB 6.1 MB/s eta 0:00:15
#    ----------- ---------------------------- 37.0/124.9 MB 6.1 MB/s eta 0:00:15
#    ----------- ---------------------------- 37.2/124.9 MB 6.0 MB/s eta 0:00:15
#    ----------- ---------------------------- 37.4/124.9 MB 6.0 MB/s eta 0:00:15
#    ------------ --------------------------- 37.6/124.9 MB 5.8 MB/s eta 0:00:15
#    ------------ --------------------------- 37.8/124.9 MB 5.8 MB/s eta 0:00:15
#    ------------ --------------------------- 38.0/124.9 MB 5.8 MB/s eta 0:00:16
#    ------------ --------------------------- 38.1/124.9 MB 5.7 MB/s eta 0:00:16
#    ------------ --------------------------- 38.4/124.9 MB 5.6 MB/s eta 0:00:16
#    ------------ --------------------------- 38.6/124.9 MB 5.6 MB/s eta 0:00:16
#    ------------ --------------------------- 38.8/124.9 MB 5.5 MB/s eta 0:00:16
#    ------------ --------------------------- 39.0/124.9 MB 5.4 MB/s eta 0:00:16
#    ------------ --------------------------- 39.2/124.9 MB 5.4 MB/s eta 0:00:16
#    ------------ --------------------------- 39.5/124.9 MB 5.4 MB/s eta 0:00:16
#    ------------ --------------------------- 39.7/124.9 MB 5.3 MB/s eta 0:00:17
#    ------------ --------------------------- 39.9/124.9 MB 5.4 MB/s eta 0:00:16
#    ------------ --------------------------- 40.2/124.9 MB 5.4 MB/s eta 0:00:16
#    ------------ --------------------------- 40.4/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 40.6/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 40.9/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 41.2/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 41.4/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 41.6/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 41.9/124.9 MB 5.3 MB/s eta 0:00:16
#    ------------- -------------------------- 42.1/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 42.4/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 42.5/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 42.8/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 43.0/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 43.2/124.9 MB 5.1 MB/s eta 0:00:16
#    ------------- -------------------------- 43.4/124.9 MB 5.2 MB/s eta 0:00:16
#    ------------- -------------------------- 43.6/124.9 MB 5.1 MB/s eta 0:00:17
#    -------------- ------------------------- 43.9/124.9 MB 5.1 MB/s eta 0:00:16
#    -------------- ------------------------- 44.2/124.9 MB 5.0 MB/s eta 0:00:17
#    -------------- ------------------------- 44.5/124.9 MB 5.0 MB/s eta 0:00:16
#    -------------- ------------------------- 44.8/124.9 MB 5.0 MB/s eta 0:00:17
#    -------------- ------------------------- 45.0/124.9 MB 5.0 MB/s eta 0:00:17
#    -------------- ------------------------- 45.2/124.9 MB 5.0 MB/s eta 0:00:17
#    -------------- ------------------------- 45.5/124.9 MB 5.0 MB/s eta 0:00:16
#    -------------- ------------------------- 45.8/124.9 MB 4.9 MB/s eta 0:00:17
#    -------------- ------------------------- 46.1/124.9 MB 4.9 MB/s eta 0:00:16
#    -------------- ------------------------- 46.4/124.9 MB 4.9 MB/s eta 0:00:16
#    -------------- ------------------------- 46.7/124.9 MB 5.0 MB/s eta 0:00:16
#    --------------- ------------------------ 47.0/124.9 MB 5.0 MB/s eta 0:00:16
#    --------------- ------------------------ 47.3/124.9 MB 5.0 MB/s eta 0:00:16
#    --------------- ------------------------ 47.7/124.9 MB 5.2 MB/s eta 0:00:15
#    --------------- ------------------------ 47.9/124.9 MB 5.2 MB/s eta 0:00:15
#    --------------- ------------------------ 48.3/124.9 MB 5.3 MB/s eta 0:00:15
#    --------------- ------------------------ 48.6/124.9 MB 5.4 MB/s eta 0:00:15
#    --------------- ------------------------ 48.8/124.9 MB 5.4 MB/s eta 0:00:15
#    --------------- ------------------------ 49.0/124.9 MB 5.4 MB/s eta 0:00:15
#    --------------- ------------------------ 49.3/124.9 MB 5.4 MB/s eta 0:00:14
#    --------------- ------------------------ 49.6/124.9 MB 5.4 MB/s eta 0:00:14
#    --------------- ------------------------ 49.9/124.9 MB 5.6 MB/s eta 0:00:14
#    ---------------- ----------------------- 50.3/124.9 MB 5.6 MB/s eta 0:00:14
#    ---------------- ----------------------- 50.6/124.9 MB 5.6 MB/s eta 0:00:14
#    ---------------- ----------------------- 50.9/124.9 MB 5.7 MB/s eta 0:00:13
#    ---------------- ----------------------- 51.2/124.9 MB 5.7 MB/s eta 0:00:13
#    ---------------- ----------------------- 51.6/124.9 MB 5.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 51.9/124.9 MB 5.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 52.3/124.9 MB 5.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 52.6/124.9 MB 6.0 MB/s eta 0:00:13
#    ---------------- ----------------------- 53.0/124.9 MB 6.1 MB/s eta 0:00:12
#    ----------------- ---------------------- 53.3/124.9 MB 6.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 53.6/124.9 MB 6.3 MB/s eta 0:00:12
#    ----------------- ---------------------- 54.0/124.9 MB 6.4 MB/s eta 0:00:12
#    ----------------- ---------------------- 54.3/124.9 MB 6.5 MB/s eta 0:00:11
#    ----------------- ---------------------- 54.7/124.9 MB 6.5 MB/s eta 0:00:11
#    ----------------- ---------------------- 55.0/124.9 MB 6.5 MB/s eta 0:00:11
#    ----------------- ---------------------- 55.3/124.9 MB 6.6 MB/s eta 0:00:11
#    ----------------- ---------------------- 55.5/124.9 MB 6.5 MB/s eta 0:00:11
#    ----------------- ---------------------- 55.7/124.9 MB 6.5 MB/s eta 0:00:11
#    ----------------- ---------------------- 55.9/124.9 MB 6.4 MB/s eta 0:00:11
#    ----------------- ---------------------- 56.0/124.9 MB 6.4 MB/s eta 0:00:11
#    ------------------ --------------------- 56.2/124.9 MB 6.3 MB/s eta 0:00:11
#    ------------------ --------------------- 56.4/124.9 MB 6.1 MB/s eta 0:00:12
#    ------------------ --------------------- 56.6/124.9 MB 6.1 MB/s eta 0:00:12
#    ------------------ --------------------- 56.9/124.9 MB 6.1 MB/s eta 0:00:12
#    ------------------ --------------------- 57.1/124.9 MB 6.1 MB/s eta 0:00:12
#    ------------------ --------------------- 57.3/124.9 MB 6.0 MB/s eta 0:00:12
#    ------------------ --------------------- 57.5/124.9 MB 6.0 MB/s eta 0:00:12
#    ------------------ --------------------- 57.8/124.9 MB 5.9 MB/s eta 0:00:12
#    ------------------ --------------------- 58.0/124.9 MB 6.0 MB/s eta 0:00:12
#    ------------------ --------------------- 58.3/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------ --------------------- 58.6/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------ --------------------- 58.8/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------ --------------------- 59.0/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------ --------------------- 59.2/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------- -------------------- 59.5/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------- -------------------- 59.8/124.9 MB 5.8 MB/s eta 0:00:12
#    ------------------- -------------------- 60.0/124.9 MB 5.7 MB/s eta 0:00:12
#    ------------------- -------------------- 60.3/124.9 MB 5.7 MB/s eta 0:00:12
#    ------------------- -------------------- 60.6/124.9 MB 5.7 MB/s eta 0:00:12
#    ------------------- -------------------- 60.9/124.9 MB 5.7 MB/s eta 0:00:12
#    ------------------- -------------------- 61.1/124.9 MB 5.6 MB/s eta 0:00:12
#    ------------------- -------------------- 61.4/124.9 MB 5.6 MB/s eta 0:00:12
#    ------------------- -------------------- 61.7/124.9 MB 5.6 MB/s eta 0:00:12
#    ------------------- -------------------- 62.0/124.9 MB 5.6 MB/s eta 0:00:12
#    ------------------- -------------------- 62.3/124.9 MB 5.6 MB/s eta 0:00:12
#    -------------------- ------------------- 62.6/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 62.9/124.9 MB 5.6 MB/s eta 0:00:12
#    -------------------- ------------------- 63.2/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 63.5/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 63.8/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 64.1/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 64.4/124.9 MB 5.5 MB/s eta 0:00:12
#    -------------------- ------------------- 64.7/124.9 MB 5.4 MB/s eta 0:00:12
#    -------------------- ------------------- 65.0/124.9 MB 5.5 MB/s eta 0:00:11
#    -------------------- ------------------- 65.3/124.9 MB 5.4 MB/s eta 0:00:12
#    --------------------- ------------------ 65.6/124.9 MB 5.5 MB/s eta 0:00:11
#    --------------------- ------------------ 65.9/124.9 MB 5.5 MB/s eta 0:00:11
#    --------------------- ------------------ 66.3/124.9 MB 5.7 MB/s eta 0:00:11
#    --------------------- ------------------ 66.6/124.9 MB 5.8 MB/s eta 0:00:11
#    --------------------- ------------------ 66.9/124.9 MB 5.8 MB/s eta 0:00:10
#    --------------------- ------------------ 67.3/124.9 MB 6.0 MB/s eta 0:00:10
#    --------------------- ------------------ 67.6/124.9 MB 6.0 MB/s eta 0:00:10
#    --------------------- ------------------ 67.9/124.9 MB 6.1 MB/s eta 0:00:10
#    --------------------- ------------------ 68.2/124.9 MB 6.1 MB/s eta 0:00:10
#    --------------------- ------------------ 68.5/124.9 MB 6.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 68.8/124.9 MB 6.2 MB/s eta 0:00:09
#    ---------------------- ----------------- 69.2/124.9 MB 6.2 MB/s eta 0:00:09
#    ---------------------- ----------------- 69.5/124.9 MB 6.4 MB/s eta 0:00:09
#    ---------------------- ----------------- 69.9/124.9 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 70.2/124.9 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 70.6/124.9 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 70.9/124.9 MB 6.7 MB/s eta 0:00:09
#    ---------------------- ----------------- 71.2/124.9 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 71.4/124.9 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 71.7/124.9 MB 6.6 MB/s eta 0:00:09
#    ----------------------- ---------------- 72.0/124.9 MB 6.5 MB/s eta 0:00:09
#    ----------------------- ---------------- 72.1/124.9 MB 6.5 MB/s eta 0:00:09
#    ----------------------- ---------------- 72.5/124.9 MB 6.5 MB/s eta 0:00:09
#    ----------------------- ---------------- 72.7/124.9 MB 6.4 MB/s eta 0:00:09
#    ----------------------- ---------------- 72.9/124.9 MB 6.4 MB/s eta 0:00:09
#    ----------------------- ---------------- 73.1/124.9 MB 6.4 MB/s eta 0:00:09
#    ----------------------- ---------------- 73.3/124.9 MB 6.3 MB/s eta 0:00:09
#    ----------------------- ---------------- 73.6/124.9 MB 6.3 MB/s eta 0:00:09
#    ----------------------- ---------------- 73.8/124.9 MB 6.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 74.1/124.9 MB 6.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 74.3/124.9 MB 6.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 74.5/124.9 MB 6.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 74.8/124.9 MB 6.1 MB/s eta 0:00:09
#    ------------------------ --------------- 75.0/124.9 MB 6.1 MB/s eta 0:00:09
#    ------------------------ --------------- 75.3/124.9 MB 6.0 MB/s eta 0:00:09
#    ------------------------ --------------- 75.5/124.9 MB 6.0 MB/s eta 0:00:09
#    ------------------------ --------------- 75.8/124.9 MB 6.0 MB/s eta 0:00:09
#    ------------------------ --------------- 76.1/124.9 MB 5.9 MB/s eta 0:00:09
#    ------------------------ --------------- 76.3/124.9 MB 5.9 MB/s eta 0:00:09
#    ------------------------ --------------- 76.6/124.9 MB 5.9 MB/s eta 0:00:09
#    ------------------------ --------------- 76.8/124.9 MB 5.8 MB/s eta 0:00:09
#    ------------------------ --------------- 77.1/124.9 MB 5.8 MB/s eta 0:00:09
#    ------------------------ --------------- 77.4/124.9 MB 5.8 MB/s eta 0:00:09
#    ------------------------ --------------- 77.7/124.9 MB 5.8 MB/s eta 0:00:09
#    ------------------------ --------------- 78.0/124.9 MB 5.8 MB/s eta 0:00:09
#    ------------------------- -------------- 78.2/124.9 MB 5.7 MB/s eta 0:00:09
#    ------------------------- -------------- 78.5/124.9 MB 5.7 MB/s eta 0:00:09
#    ------------------------- -------------- 78.8/124.9 MB 5.7 MB/s eta 0:00:09
#    ------------------------- -------------- 79.0/124.9 MB 5.7 MB/s eta 0:00:09
#    ------------------------- -------------- 79.3/124.9 MB 5.6 MB/s eta 0:00:09
#    ------------------------- -------------- 79.6/124.9 MB 5.6 MB/s eta 0:00:09
#    ------------------------- -------------- 79.8/124.9 MB 5.5 MB/s eta 0:00:09
#    ------------------------- -------------- 80.0/124.9 MB 5.5 MB/s eta 0:00:09
#    ------------------------- -------------- 80.2/124.9 MB 5.4 MB/s eta 0:00:09
#    ------------------------- -------------- 80.5/124.9 MB 5.4 MB/s eta 0:00:09
#    ------------------------- -------------- 80.8/124.9 MB 5.4 MB/s eta 0:00:09
#    ------------------------- -------------- 81.2/124.9 MB 5.4 MB/s eta 0:00:09
#    -------------------------- ------------- 81.5/124.9 MB 5.4 MB/s eta 0:00:09
#    -------------------------- ------------- 81.8/124.9 MB 5.5 MB/s eta 0:00:08
#    -------------------------- ------------- 82.2/124.9 MB 5.5 MB/s eta 0:00:08
#    -------------------------- ------------- 82.4/124.9 MB 5.5 MB/s eta 0:00:08
#    -------------------------- ------------- 82.8/124.9 MB 5.5 MB/s eta 0:00:08
#    -------------------------- ------------- 83.1/124.9 MB 5.7 MB/s eta 0:00:08
#    -------------------------- ------------- 83.4/124.9 MB 5.7 MB/s eta 0:00:08
#    -------------------------- ------------- 83.8/124.9 MB 5.7 MB/s eta 0:00:08
#    -------------------------- ------------- 84.1/124.9 MB 5.8 MB/s eta 0:00:07
#    --------------------------- ------------ 84.4/124.9 MB 5.9 MB/s eta 0:00:07
#    --------------------------- ------------ 84.8/124.9 MB 6.0 MB/s eta 0:00:07
#    --------------------------- ------------ 85.1/124.9 MB 6.1 MB/s eta 0:00:07
#    --------------------------- ------------ 85.4/124.9 MB 6.1 MB/s eta 0:00:07
#    --------------------------- ------------ 85.8/124.9 MB 6.2 MB/s eta 0:00:07
#    --------------------------- ------------ 86.1/124.9 MB 6.2 MB/s eta 0:00:07
#    --------------------------- ------------ 86.4/124.9 MB 6.2 MB/s eta 0:00:07
#    --------------------------- ------------ 86.7/124.9 MB 6.2 MB/s eta 0:00:07
#    --------------------------- ------------ 86.9/124.9 MB 6.2 MB/s eta 0:00:07
#    --------------------------- ------------ 87.2/124.9 MB 6.2 MB/s eta 0:00:07
#    ---------------------------- ----------- 87.5/124.9 MB 6.2 MB/s eta 0:00:07
#    ---------------------------- ----------- 87.8/124.9 MB 6.2 MB/s eta 0:00:07
#    ---------------------------- ----------- 88.0/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 88.3/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 88.5/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 88.9/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 89.1/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 89.4/124.9 MB 6.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 89.7/124.9 MB 6.3 MB/s eta 0:00:06
#    ---------------------------- ----------- 90.0/124.9 MB 6.3 MB/s eta 0:00:06
#    ---------------------------- ----------- 90.2/124.9 MB 6.3 MB/s eta 0:00:06
#    ---------------------------- ----------- 90.5/124.9 MB 6.4 MB/s eta 0:00:06
#    ----------------------------- ---------- 90.8/124.9 MB 6.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 91.1/124.9 MB 6.4 MB/s eta 0:00:06
#    ----------------------------- ---------- 91.4/124.9 MB 6.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 91.6/124.9 MB 6.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 91.8/124.9 MB 6.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 92.1/124.9 MB 6.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 92.3/124.9 MB 6.1 MB/s eta 0:00:06
#    ----------------------------- ---------- 92.6/124.9 MB 6.1 MB/s eta 0:00:06
#    ----------------------------- ---------- 92.9/124.9 MB 6.1 MB/s eta 0:00:06
#    ----------------------------- ---------- 93.2/124.9 MB 6.1 MB/s eta 0:00:06
#    ----------------------------- ---------- 93.6/124.9 MB 6.1 MB/s eta 0:00:06
#    ------------------------------ --------- 93.9/124.9 MB 6.1 MB/s eta 0:00:06
#    ------------------------------ --------- 94.3/124.9 MB 6.1 MB/s eta 0:00:06
#    ------------------------------ --------- 94.6/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 94.9/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 95.3/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 95.5/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 95.9/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 96.2/124.9 MB 6.0 MB/s eta 0:00:05
#    ------------------------------ --------- 96.5/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 96.8/124.9 MB 6.0 MB/s eta 0:00:05
#    ------------------------------- -------- 97.1/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 97.5/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 97.8/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 98.1/124.9 MB 6.3 MB/s eta 0:00:05
#    ------------------------------- -------- 98.5/124.9 MB 6.3 MB/s eta 0:00:05
#    ------------------------------- -------- 98.7/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 98.9/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 99.1/124.9 MB 6.2 MB/s eta 0:00:05
#    ------------------------------- -------- 99.3/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------- -------- 99.6/124.9 MB 6.1 MB/s eta 0:00:05
#    ------------------------------- -------- 99.8/124.9 MB 6.1 MB/s eta 0:00:05
#    -------------------------------- ------- 100.0/124.9 MB 6.1 MB/s eta 0:00:05
#    -------------------------------- ------- 100.2/124.9 MB 6.0 MB/s eta 0:00:05
#    -------------------------------- ------- 100.5/124.9 MB 6.0 MB/s eta 0:00:05
#    -------------------------------- ------- 100.7/124.9 MB 5.9 MB/s eta 0:00:05
#    -------------------------------- ------- 100.9/124.9 MB 5.9 MB/s eta 0:00:05
#    -------------------------------- ------- 101.1/124.9 MB 5.9 MB/s eta 0:00:05
#    -------------------------------- ------- 101.4/124.9 MB 5.8 MB/s eta 0:00:05
#    -------------------------------- ------- 101.6/124.9 MB 5.8 MB/s eta 0:00:04
#    -------------------------------- ------- 101.8/124.9 MB 5.8 MB/s eta 0:00:04
#    -------------------------------- ------- 102.1/124.9 MB 5.8 MB/s eta 0:00:04
#    -------------------------------- ------- 102.4/124.9 MB 5.8 MB/s eta 0:00:04
#    -------------------------------- ------- 102.6/124.9 MB 5.8 MB/s eta 0:00:04
#    -------------------------------- ------- 102.9/124.9 MB 5.8 MB/s eta 0:00:04
#    --------------------------------- ------ 103.1/124.9 MB 5.8 MB/s eta 0:00:04
#    --------------------------------- ------ 103.4/124.9 MB 5.8 MB/s eta 0:00:04
#    --------------------------------- ------ 103.6/124.9 MB 5.7 MB/s eta 0:00:04
#    --------------------------------- ------ 103.8/124.9 MB 5.7 MB/s eta 0:00:04
#    --------------------------------- ------ 104.0/124.9 MB 5.6 MB/s eta 0:00:04
#    --------------------------------- ------ 104.2/124.9 MB 5.6 MB/s eta 0:00:04
#    --------------------------------- ------ 104.3/124.9 MB 5.5 MB/s eta 0:00:04
#    --------------------------------- ------ 104.5/124.9 MB 5.4 MB/s eta 0:00:04
#    --------------------------------- ------ 104.7/124.9 MB 5.3 MB/s eta 0:00:04
#    --------------------------------- ------ 104.9/124.9 MB 5.3 MB/s eta 0:00:04
#    --------------------------------- ------ 105.1/124.9 MB 5.3 MB/s eta 0:00:04
#    --------------------------------- ------ 105.4/124.9 MB 5.2 MB/s eta 0:00:04
#    --------------------------------- ------ 105.6/124.9 MB 5.2 MB/s eta 0:00:04
#    --------------------------------- ------ 105.8/124.9 MB 5.2 MB/s eta 0:00:04
#    --------------------------------- ------ 106.1/124.9 MB 5.1 MB/s eta 0:00:04
#    ---------------------------------- ----- 106.3/124.9 MB 5.1 MB/s eta 0:00:04
#    ---------------------------------- ----- 106.5/124.9 MB 5.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 106.8/124.9 MB 5.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.0/124.9 MB 5.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.3/124.9 MB 5.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.5/124.9 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.7/124.9 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 108.0/124.9 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 108.3/124.9 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 108.5/124.9 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 108.8/124.9 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 109.0/124.9 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 109.3/124.9 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 109.4/124.9 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 109.7/124.9 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 109.9/124.9 MB 4.9 MB/s eta 0:00:04
#    ----------------------------------- ---- 110.2/124.9 MB 4.9 MB/s eta 0:00:04
#    ----------------------------------- ---- 110.5/124.9 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 110.8/124.9 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.1/124.9 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.4/124.9 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.6/124.9 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.9/124.9 MB 5.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 112.2/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 112.5/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 112.8/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 113.1/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 113.3/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 113.6/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 113.9/124.9 MB 5.2 MB/s eta 0:00:03
#    ------------------------------------ --- 114.1/124.9 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------ --- 114.4/124.9 MB 5.2 MB/s eta 0:00:03
#    ------------------------------------ --- 114.7/124.9 MB 5.4 MB/s eta 0:00:02
#    ------------------------------------ --- 115.0/124.9 MB 5.4 MB/s eta 0:00:02
#    ------------------------------------ --- 115.2/124.9 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------ --- 115.4/124.9 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------- -- 115.8/124.9 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------- -- 116.1/124.9 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------- -- 116.4/124.9 MB 5.6 MB/s eta 0:00:02
#    ------------------------------------- -- 116.7/124.9 MB 5.6 MB/s eta 0:00:02
#    ------------------------------------- -- 117.0/124.9 MB 5.7 MB/s eta 0:00:02
#    ------------------------------------- -- 117.4/124.9 MB 5.7 MB/s eta 0:00:02
#    ------------------------------------- -- 117.7/124.9 MB 5.8 MB/s eta 0:00:02
#    ------------------------------------- -- 118.0/124.9 MB 5.8 MB/s eta 0:00:02
#    ------------------------------------- -- 118.4/124.9 MB 5.8 MB/s eta 0:00:02
#    ------------------------------------- -- 118.7/124.9 MB 5.9 MB/s eta 0:00:02
#    -------------------------------------- - 118.9/124.9 MB 5.9 MB/s eta 0:00:02
#    -------------------------------------- - 119.3/124.9 MB 6.0 MB/s eta 0:00:01
#    -------------------------------------- - 119.7/124.9 MB 6.1 MB/s eta 0:00:01
#    -------------------------------------- - 120.1/124.9 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 120.4/124.9 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 120.8/124.9 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 121.0/124.9 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 121.4/124.9 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 121.7/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  121.9/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  122.3/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  122.6/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  122.8/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  123.1/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  123.4/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  123.7/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.3/124.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  124.5/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.8/124.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 5.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.0

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
  trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\samar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9650953710319118
# 2.3887090801112776

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))
import xgboost
xgboost.__version__
# Out:
# '2.1.0'
